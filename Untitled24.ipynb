# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchada2000/MY-WORK/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style("whitegrid")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data1 = pd.read_excel('/content/drive/MyDrive/project/example.xlsx')

# %%
data1.head()
# Out:
#    ID  Age Gender  Career  No_policy  No_claim  Insurance premium  \
# 0   1   30      m       1          2         1               3000
# 1   2   35      f       4          2         2               5000
# 2   3   21      f       5          3         2               1500
# 3   4   25      f       3          3         1               3500
# 4   5   40      f       1          3         3               4000
#
#   Result_claim  Payment  Time_information Conversation  Speed  Time  result
# 0        claim  on time                 1       normal      1     1  honest
# 1        claim     late                 0       normal      5     2   Fraud
# 2       reject  on time                 0       normal      3     5  honest
# 3       reject  on time                 0          bad      2     4  honest
# 4        claim     late                 2       normal      1     2  honest

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X.iloc[:, 6] = labelencoder_X.fit_transform(X.iloc[:, 6])
X.iloc[:, 7] = labelencoder_X.fit_transform(X.iloc[:, 7])
X.iloc[:, 9] = labelencoder_X.fit_transform(X.iloc[:, 9])
X.head()
# Out:
#    ID  Age Gender  Career  No_policy  No_claim  Insurance premium  \
# 0   1   30      1       1          2         1                  2
# 1   2   35      0       4          2         2                  5
# 2   3   21      0       5          3         2                  0
# 3   4   25      0       3          3         1                  3
# 4   5   40      0       1          3         3                  4
#
#   Result_claim Payment  Time_information Conversation  Speed  Time  Class
# 0            0       1                 1            1      1     0      1
# 1            0       0                 0            1      5     1      0
# 2            1       1                 0            1      3     3      1
# 3            1       1                 0            0      2     2      1
# 4            0       0                 2            1      1     1      1

# %%
pd.set_option("display.float", "{:.2f}".format)
data.describe()
#ทศนิยมแค่ 2 ตัว
# Out:
#        Gender  Result_claim  Payment  Conversation
# count    4.00          4.00     4.00          4.00
# mean     0.00          0.00     0.00          0.00
# std      0.00          0.00     0.00          0.00
# min      0.00          0.00     0.00          0.00
# 25%      0.00          0.00     0.00          0.00
# 50%      0.00          0.00     0.00          0.00
# 75%      0.00          0.00     0.00          0.00
# max      0.00          0.00     0.00          0.00

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Career', 'No_policy', 'No_claim',
#        'Insurance premium', 'Result_claim', 'Payment', 'Time_information',
#        'Conversation', 'Speed', 'Time', 'result'],
#       dtype='object')

# %%
LABELS = ["honest", "Fraud"]

count_classes = pd.value_counts(data['result'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction Class Distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("result")
plt.ylabel("Frequency");
# Out:
# <ipython-input-14-0efbbab6d084>:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   count_classes = pd.value_counts(data['result'], sort = True)

# %%
data.result.value_counts()
# Out:
# result
# honest    79
# Fraud     21
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# สร้าง LabelEncoder
labelencoder = LabelEncoder()

# แปลงคอลัมน์ 'Class' จากข้อความเป็นตัวเลข
data['result'] = labelencoder.fit_transform(data['result'])

# ตรวจสอบผลลัพธ์
print(data['result'].unique())
# Out:
# [1 0]

# %%
Fraud = data[data['result']==1]
honest = data[data['result']==0]

print(f"Shape of Fraudulant transactions: {Fraud.shape}")
print(f"Shape of Non-Fraudulant transactions: {honest.shape}")
#(แถว, คอลัม)
# Out:
# Shape of Fraudulant transactions: (79, 15)
# Shape of Non-Fraudulant transactions: (21, 15)

# %%
pd.concat([Fraud['Insurance premium'].describe(), honest['Insurance premium'].describe()], axis=1)
# Out:
#        Insurance premium  Insurance premium
# count              79.00              21.00
# mean             3696.20            3166.67
# std              1426.44            1791.18
# min              1500.00            1500.00
# 25%              3000.00            1500.00
# 50%              3500.00            1500.00
# 75%              5000.00            5000.00
# max              6500.00            5000.00

# %%
#ธุรกรรมฉ้อโกงมักเกิดขึ้นบ่อยขึ้นในกรอบเวลาบางช่วงหรือไม่?
pd.concat([Fraud.Time.describe(), honest.Time.describe()], axis=1)
# Out:
#        Time  Time
# count 79.00 21.00
# mean   3.53  3.05
# std    2.35  1.02
# min    1.00  2.00
# 25%    2.00  2.00
# 50%    4.00  4.00
# 75%    5.00  4.00
# max    8.00  4.00

# %%
# plot the time feature
plt.figure(figsize=(14,10))

plt.subplot(2, 2, 1)
plt.title('Time Distribution (Seconds)')

sns.displot(data['Time'], color='blue');

#plot the amount feature
plt.subplot(2, 2, 2)
plt.title('Distribution of Insurance premium')
sns.displot(data['Insurance premium'],color='blue');

# %%
import matplotlib.pyplot as plt

# Create a figure with specific size
plt.figure(figsize=(14, 12))

# Plot for fraudulent transactions (Class == 1)
plt.subplot(2, 2, 1)
data[data.Class == 1].Time.hist(bins=35, color='blue', alpha=0.6, label="Fraudulent Transaction")
plt.title('Fraudulent Transactions - Time Distribution')
plt.legend()

# Plot for non-fraudulent transactions (Class == 0)
plt.subplot(2, 2, 2)
data[data.Class == 0].Time.hist(bins=35, color='blue', alpha=0.6, label="Non-Fraudulent Transaction")
plt.title('Non-Fraudulent Transactions - Time Distribution')
plt.legend()

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
data['Time'] = pd.to_numeric(data['Time'], errors='coerce')
# ตรวจสอบข้อมูลที่มีค่า NaN หลังจากการแปลง
print(data['Time'].isnull().sum())  # ดูจำนวนค่า NaN ที่เกิดขึ้น

# ลบหรือเติมค่า NaN หากต้องการ
data = data.dropna(subset=['Time'])  # ลบแถวที่มีค่า NaN ในคอลัมน์ 'Time'

# ตอนนี้ทำการ plot ได้ตามปกติ
plt.figure(figsize=(14, 12))

plt.subplot(2, 2, 1)
data[data.Class == 1].Time.hist(bins=35, color='blue', alpha=0.6, label="Fraudulent Transaction")
plt.title('Fraudulent Transactions - Time Distribution')
plt.legend()

plt.subplot(2, 2, 2)
data[data.Class == 0].Time.hist(bins=35, color='blue', alpha=0.6, label="Non-Fraudulent Transaction")
plt.title('Non-Fraudulent Transactions - Time Distribution')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 0

# %%
print(data.dtypes)
# Out:
# ID                    int64
# Age                   int64
# Gender               object
# Career                int64
# No_policy             int64
# No_claim              int64
# Insurance premium     int64
# Result_claim         object
# Payment              object
# Time_information      int64
# Conversation         object
# Speed                 int64
# Time                  int64
# result                int64
# Class                 int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# ใช้ LabelEncoder แปลงคอลัมน์ที่มีค่าหมวดหมู่
labelencoder = LabelEncoder()
data['Time'] = labelencoder.fit_transform(data['Time'])

# %%
data['Time'] = pd.to_numeric(data['Time'], errors='coerce')

# %%
data_numeric = data.select_dtypes(include=['number'])

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(data_numeric.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5, center=0)
plt.title('Correlation Heatmap')
plt.show()
#ค่ามากแปลว่ามีความสัมพันกันสูง

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()

X = data.drop('result', axis=1)
y = data.Class

X_train_v, X_test, y_train_v, y_test = train_test_split(X, y,
                                                    test_size=0.3, random_state=42)
X_train, X_validate, y_train, y_validate = train_test_split(X_train_v, y_train_v,
                                                            test_size=0.2, random_state=42)

X_train = scalar.fit_transform(X_train)
X_validate = scalar.transform(X_validate)
X_test = scalar.transform(X_test)

w_p = y_train.value_counts()[0] / len(y_train)
w_n = y_train.value_counts()[1] / len(y_train)

print(f"Fraudulant transaction weight: {w_n}")
print(f"Non-Fraudulant transaction weight: {w_p}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-a6e86c1138be> in <cell line: 14>()
#      12                                                             test_size=0.2, random_state=42)
#      13
# ---> 14 X_train = scalar.fit_transform(X_train)
#      15 X_validate = scalar.transform(X_validate)
#      16 X_test = scalar.transform(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#    1096         if y is None:
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()

X = data.drop('Class', axis=1)
y = data.Class

X_train_v, X_test, y_train_v, y_test = train_test_split(X, y,
                                                    test_size=0.3, random_state=42)
X_train, X_validate, y_train, y_validate = train_test_split(X_train_v, y_train_v,
                                                            test_size=0.2, random_state=42)

X_train = scalar.fit_transform(X_train)
X_validate = scalar.transform(X_validate)
X_test = scalar.transform(X_test)

w_p = y_train.value_counts()[0] / len(y_train)
w_n = y_train.value_counts()[1] / len(y_train)

print(f"Fraudulant transaction weight: {w_n}")
print(f"Non-Fraudulant transaction weight: {w_p}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-148-789a17f1c6a3> in <cell line: 6>()
#       4 scalar = StandardScaler()
#       5
# ----> 6 X = data.drop('Class', axis=1)
#       7 y = data.Class
#       8
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
# ...

# %%
print(f"TRAINING: X_train: {X_train.shape}, y_train: {y_train.shape}\n{'_'*55}")
print(f"VALIDATION: X_validate: {X_validate.shape}, y_validate: {y_validate.shape}\n{'_'*50}")
print(f"TESTING: X_test: {X_test.shape}, y_test: {y_test.shape}")

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score

def print_score(label, prediction, train=True):
    if train:
        clf_report = pd.DataFrame(classification_report(label, prediction, output_dict=True))
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(label, prediction) * 100:.2f}%")
        print("_______________________________________________")
        print(f"Classification Report:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_train, prediction)}\n")

    elif train==False:
        clf_report = pd.DataFrame(classification_report(label, prediction, output_dict=True))
        print("Test Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(label, prediction) * 100:.2f}%")
        print("_______________________________________________")
        print(f"Classification Report:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(label, prediction)}\n")

# %%
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[-1],)),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(1, activation='sigmoid'),
])

model.summary()

# %%
METRICS = [
#     keras.metrics.Accuracy(name='accuracy'),
    keras.metrics.FalseNegatives(name='fn'),
    keras.metrics.FalsePositives(name='fp'),
    keras.metrics.TrueNegatives(name='tn'),
    keras.metrics.TruePositives(name='tp'),
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

model.compile(optimizer=keras.optimizers.Adam(1e-4), loss='binary_crossentropy', metrics=METRICS)

callbacks = [keras.callbacks.ModelCheckpoint('fraud_model_at_epoch_{epoch}.h5')]
class_weight = {0:w_p, 1:w_n}

r = model.fit(
    X_train, y_train,
    validation_data=(X_validate, y_validate),
    batch_size=2048,
    epochs=300,
#     class_weight=class_weight,
    callbacks=callbacks,
)

# %%
score = model.evaluate(X_test, y_test)
print(score)

# %%
plt.figure(figsize=(12, 16))

plt.subplot(4, 2, 1)
plt.plot(r.history['loss'], label='Loss')
plt.plot(r.history['val_loss'], label='val_Loss')
plt.title('Loss Function evolution during training')
plt.legend()

plt.subplot(4, 2, 2)
plt.plot(r.history['fn'], label='fn')
plt.plot(r.history['val_fn'], label='val_fn')
plt.title('Accuracy evolution during training')
plt.legend()

plt.subplot(4, 2, 3)
plt.plot(r.history['precision'], label='precision')
plt.plot(r.history['val_precision'], label='val_precision')
plt.title('Precision evolution during training')
plt.legend()

plt.subplot(4, 2, 4)
plt.plot(r.history['recall'], label='recall')
plt.plot(r.history['val_recall'], label='val_recall')
plt.title('Recall evolution during training')
plt.legend()

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

print_score(y_train, y_train_pred.round(), train=True)
print_score(y_test, y_test_pred.round(), train=False)

scores_dict = {
    'ANNs': {
        'Train': f1_score(y_train, y_train_pred.round()),
        'Test': f1_score(y_test, y_test_pred.round()),
    },
}
