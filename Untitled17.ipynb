# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchada2000/MY-WORK/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
# %matplotlib inline

import os
import pandas as pd
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('/content/drive/MyDrive/project/example.xlsx')

# %%
df.shape #14column 10row
# Out:
# (100, 14)

# %%
df.head()
# Out:
#    ID  Age Gender  Career  No_policy  No_claim  Insurance premium  \
# 0   1   30      m       1          2         1               3000
# 1   2   35      f       4          2         2               5000
# 2   3   21      f       5          3         2               1500
# 3   4   25      f       3          3         1               3500
# 4   5   40      f       1          3         3               4000
#
#   Result_claim  Payment  Time_information Conversation  Speed  Time  result
# 0        claim  on time                 1       normal      1     1  honest
# 1        claim     late                 0       normal      5     2   Fraud
# 2       reject  on time                 0       normal      3     5  honest
# 3       reject  on time                 0          bad      2     4  honest
# 4        claim     late                 2       normal      1     2  honest

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
df['Result_claim'] = le.fit_transform(df['Result_claim'])
df['Payment'] = le.fit_transform(df['Payment'])
df['Conversation'] = le.fit_transform(df['Conversation'])

# %%
df.head()
# Out:
#    ID  Age  Gender  Career  No_policy  No_claim  Insurance premium  \
# 0   1   30       1       1          2         1               3000
# 1   2   35       0       4          2         2               5000
# 2   3   21       0       5          3         2               1500
# 3   4   25       0       3          3         1               3500
# 4   5   40       0       1          3         3               4000
#
#    Result_claim  Payment  Time_information  Conversation  Speed  Time  result
# 0             0        1                 1             1      1     1  honest
# 1             0        0                 0             1      5     2   Fraud
# 2             1        1                 0             1      3     5  honest
# 3             1        1                 0             0      2     4  honest
# 4             0        0                 2             1      1     2  honest

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 100 non-null    int64
#  1   Age                100 non-null    int64
#  2   Gender             100 non-null    int64
#  3   Career             100 non-null    int64
#  4   No_policy          100 non-null    int64
#  5   No_claim           100 non-null    int64
#  6   Insurance premium  100 non-null    int64
#  7   Result_claim       100 non-null    int64
#  8   Payment            100 non-null    int64
#  9   Time_information   100 non-null    int64
#  10  Conversation       100 non-null    int64
#  11  Speed              100 non-null    int64
#  12  Time               100 non-null    int64
#  13  result             100 non-null    object
# dtypes: int64(13), object(1)
# memory usage: 11.1+ KB

# %%
col_names = ['ID', 'Age', 'Gender', 'Career', 'No_policy', 'No_claim', 'Insurance premium', 'Result_claim', 'Payment', 'Time_information', 'Conversation', 'Speed', 'Time', 'result']


for col in col_names:

    print(df[col].value_counts())
    #ดูจำนวนของแต่ละคอลัมว่ามีข้อมูลแบบไหนกี่จำนวน
# Out:
# ID
# 1      1
# 64     1
# 74     1
# 73     1
# 72     1
#       ..
# 31     1
# 30     1
# 29     1
# 28     1
# 100    1
# Name: count, Length: 100, dtype: int64
# Age
# 23    14
# 45    12
# 21    10
# 22     8
# 65     8
# 20     8
# 30     6
# 2      6
# 28     6
# 3      4
# 67     2
# 77     2
# 43     2
# 6      2
# 25     2
# 33     2
# 29     1
# 35     1
# 57     1
# 60     1
# 44     1
# 40     1
# Name: count, dtype: int64
# Gender
# 0    60
# 1    40
# Name: count, dtype: int64
# Career
# 1    23
# 3    20
# 5    19
# 8    12
# 9    11
# 4    10
# 2     5
# Name: count, dtype: int64
# No_policy
# 3    49
# 2    39
# 1    12
# Name: count, dtype: int64
# No_claim
# 1    51
# 2    40
# 3     9
# Name: count, dtype: int64
# Insurance premium
# 5000    22
# 1500    21
# 3500    20
# 3000    10
# 4000     9
# 6500     9
# 2500     9
# Name: count, dtype: int64
# Result_claim
# 0    51
# 1    49
# Name: count, dtype: int64
# Payment
# 1    52
# 0    48
# ...

# %%
df.isnull().sum()
# Out:
# ID                   0
# Age                  0
# Gender               0
# Career               0
# No_policy            0
# No_claim             0
# Insurance premium    0
# Result_claim         0
# Payment              0
# Time_information     0
# Conversation         0
# Speed                0
# Time                 0
# result               0
# dtype: int64

# %%
X = df.drop(['result'], axis=1)

y = df['result']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
X_train.shape, X_test.shape
#6แถว(Training set) 13คอลัมน์ 4แถว(Test set)13คอลัมน์
# Out:
# ((67, 13), (33, 13))

# %%
X_train.dtypes
# Out:
# ID                   int64
# Age                  int64
# Gender               int64
# Career               int64
# No_policy            int64
# No_claim             int64
# Insurance premium    int64
# Result_claim         int64
# Payment              int64
# Time_information     int64
# Conversation         int64
# Speed                int64
# Time                 int64
# dtype: object

# %%
X_train
# Out:
#     ID  Age  Gender  Career  No_policy  No_claim  Insurance premium  \
# 28  29   33       1       4          2         2               5000
# 93  94   23       1       1          2         1               3000
# 5    6   44       1       8          1         1               5000
# 66  67    2       1       1          3         2               2500
# 65  66   65       0       5          2         1               6500
# ..  ..  ...     ...     ...        ...       ...                ...
# 60  61   30       0       5          2         1               6500
# 71  72   21       0       8          3         3               4000
# 14  15   45       0       1          2         1               3000
# 92  93   20       0       1          3         2               2500
# 51  52   21       0       1          3         2               2500
#
#     Result_claim  Payment  Time_information  Conversation  Speed  Time
# 28             0        0                 0             1      5     2
# ...

# %%
X_train.head()
# Out:
#     ID  Age  Gender  Career  No_policy  No_claim  Insurance premium  \
# 28  29   33       1       4          2         2               5000
# 93  94   23       1       1          2         1               3000
# 5    6   44       1       8          1         1               5000
# 66  67    2       1       1          3         2               2500
# 65  66   65       0       5          2         1               6500
#
#     Result_claim  Payment  Time_information  Conversation  Speed  Time
# 28             0        0                 0             1      5     2
# 93             0        1                 1             1      1     1
# 5              0        1                 0             1      2     8
# 66             1        0                 0             1      2     4
# 65             1        0                 3             1      5     1

# %%
# !pip install category_encoders

# %%
import category_encoders as ce

# %%
encoder = ce.OrdinalEncoder(cols=['ID', 'Age', 'Gender', 'Career', 'No_policy', 'No_claim', 'Insurance premium', 'Result_claim', 'Payment', 'Time_information', 'Conversation', 'Speed', 'Time'])


X_train = encoder.fit_transform(X_train)

X_test = encoder.transform(X_test)

# %%
X_train.head()
# Out:
#     ID  Age  Gender  Career  No_policy  No_claim  Insurance premium  \
# 28   1    1       1       1          1         1                  1
# 93   2    2       1       2          1         2                  2
# 5    3    3       1       3          2         2                  1
# 66   4    4       1       2          3         1                  3
# 65   5    5       2       4          1         2                  4
#
#     Result_claim  Payment  Time_information  Conversation  Speed  Time
# 28             1        1                 1             1      1     1
# 93             1        2                 2             1      2     2
# 5              1        2                 1             1      3     3
# 66             2        1                 1             1      3     4
# 65             2        1                 3             1      1     2

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# สร้างโมเดล
model = DecisionTreeClassifier()

# กำหนดช่วงของ max_depth ที่ต้องการทดสอบ
param_grid = {'max_depth': [3, 5, 10, 15, 20, None]}

# ใช้ GridSearchCV เพื่อหาค่าที่ดีที่สุด
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

# แสดงผลลัพธ์ที่ดีที่สุด
print("Best max_depth:", grid_search.best_params_['max_depth'])
#ช่วยลด overfitting
# Out:
# Best max_depth: 3

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# กำหนดโมเดล
model = DecisionTreeClassifier()

# กำหนดพารามิเตอร์ที่ต้องการทดสอบ
param_grid = {'min_samples_split': [2, 10, 20, 50, 100]}

# ใช้ Grid Search เพื่อหาค่าที่ดีที่สุด
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

# แสดงผลลัพธ์ที่ดีที่สุด
print("Best min_samples_split:", grid_search.best_params_['min_samples_split'])
# Out:
# Best min_samples_split: 2

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# กำหนดโมเดล
model = DecisionTreeClassifier()

# กำหนดพารามิเตอร์ที่ต้องการทดสอบ
param_grid = {'min_samples_leaf': [1, 2, 5, 10, 20]}

# ใช้ Grid Search เพื่อหาค่าที่ดีที่สุด
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

# แสดงผลลัพธ์ที่ดีที่สุด
print("Best min_samples_leaf:", grid_search.best_params_['min_samples_leaf'])
# Out:
# Best min_samples_leaf: 1

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100)  # สร้าง Random Forest ด้วย 100 ต้นไม้
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
model = RandomForestClassifier(max_features="sqrt", min_impurity_decrease=0.01)

# %%
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=5, random_state=0,min_samples_split=20,min_samples_leaf=2)


# fit the model
clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=20,
#                        random_state=0)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(clf_gini, X_train, y_train, cv=5)  # ใช้ 5-fold cross-validation
print(scores)
# Out:
# [1.         0.71428571 1.         1.         1.        ]

# %%
y_pred_gini = clf_gini.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion gini index: {0:0.4f}'. format(accuracy_score(y_test, y_pred_gini)))
#คะแนนความแม่นยำของแบบจำลองโดยใช้ดัชนี gini ตามเกณฑ์: 0.75เปรียบเทียบความแม่นยำของชุดฝึกและชุดทดสอบเพื่อตรวจสอบการโอเวอร์ฟิตติ้ง
# Out:
# Model accuracy score with criterion gini index: 1.0000

# %%
y_pred_train_gini = clf_gini.predict(X_train)

y_pred_train_gini
# Out:
# array(['Fraud', 'honest', 'honest', 'honest', 'honest', 'honest',
#        'honest', 'honest', 'honest', 'honest', 'honest', 'honest',
#        'honest', 'honest', 'honest', 'honest', 'honest', 'honest',
#        'honest', 'honest', 'Fraud', 'honest', 'Fraud', 'Fraud', 'honest',
#        'honest', 'Fraud', 'honest', 'Fraud', 'honest', 'Fraud', 'honest',
#        'honest', 'honest', 'Fraud', 'honest', 'honest', 'honest',
#        'honest', 'Fraud', 'Fraud', 'honest', 'honest', 'honest', 'honest',
#        'Fraud', 'honest', 'Fraud', 'honest', 'honest', 'honest', 'Fraud',
#        'honest', 'honest', 'honest', 'Fraud', 'honest', 'honest',
#        'honest', 'honest', 'honest', 'Fraud', 'honest', 'honest',
#        'honest', 'honest', 'honest'], dtype=object)

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_gini)))
# Out:
# Training-set accuracy score: 1.0000

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(clf_gini.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf_gini.score(X_test, y_test)))
# Out:
# Training set score: 1.0000
# Test set score: 1.0000

# %%
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_gini.fit(X_train, y_train))
# Out:
# [Text(0.6, 0.8333333333333334, 'x[11] <= 4.5\ngini = 0.348\nsamples = 67\nvalue = [15, 52]'),
#  Text(0.4, 0.5, 'x[3] <= 1.5\ngini = 0.185\nsamples = 58\nvalue = [6, 52]'),
#  Text(0.5, 0.6666666666666667, 'True  '),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.0\nsamples = 52\nvalue = [0, 52]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.7, 0.6666666666666667, '  False')]

# %% [markdown]
# ![Screenshot 2024-12-01 104915.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# มีความหมายว่าตัวแปรที่ 11 หมายถึง speed จำนวนครั้งของการเร่งรีบ ไม่นัลคอลัมแรกเพราะถือว่าเป็นคอลัม 0 /// มีค่าน้ยกว่า 4.5 จะไปทางซ้าย
#
# gini การตัดสินใจจะแยกโหนดต่อไปเพื่อพยายามลดค่าความไม่บริสุทธิ์นี้ให้ใกล้ 0 มากขึ้น เพื่อให้โหนดปลายทางมีคลาสที่ชัดเจน ในที่นี้มี2class
# value 0=ford 1=honest
# vale =[9,0]แสดงว่า ford

# %%
import numpy as np

num = np.int64(42)  # ตัวแปร numpy.int64
text = "The number is: "

# เกิดข้อผิดพลาด:
# result = text + num  # จะเกิด error

# วิธีแก้ไข:
result = text + str(num)  # แปลง num เป็น str ก่อน
print(result)  # Output: "The number is: 42"
# Out:
# The number is: 42

# %%
import graphviz
dot_data = tree.export_graphviz(clf_gini, out_file=None,
                              feature_names=X_train.columns,
                              class_names=y_train,
                              filled=True, rounded=True,
                              special_characters=True)

graph = graphviz.Source(dot_data)

graph

# %%
clf_en = DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=0,min_samples_split=20,min_samples_leaf=2)


# fit the model
clf_en.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=2,
#                        min_samples_split=20, random_state=0)

# %%
y_pred_en = clf_en.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion entropy: {0:0.4f}'. format(accuracy_score(y_test, y_pred_en)))
# Out:
# Model accuracy score with criterion entropy: 1.0000

# %%
y_pred_train_en = clf_en.predict(X_train)

y_pred_train_en
# Out:
# array(['Fraud', 'honest', 'honest', 'honest', 'honest', 'honest',
#        'honest', 'honest', 'honest', 'honest', 'honest', 'honest',
#        'honest', 'honest', 'honest', 'honest', 'honest', 'honest',
#        'honest', 'honest', 'Fraud', 'honest', 'Fraud', 'Fraud', 'honest',
#        'honest', 'Fraud', 'honest', 'Fraud', 'honest', 'Fraud', 'honest',
#        'honest', 'honest', 'Fraud', 'honest', 'honest', 'honest',
#        'honest', 'Fraud', 'Fraud', 'honest', 'honest', 'honest', 'honest',
#        'Fraud', 'honest', 'Fraud', 'honest', 'honest', 'honest', 'Fraud',
#        'honest', 'honest', 'honest', 'Fraud', 'honest', 'honest',
#        'honest', 'honest', 'honest', 'Fraud', 'honest', 'honest',
#        'honest', 'honest', 'honest'], dtype=object)

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_en)))
# Out:
# Training-set accuracy score: 1.0000

# %%
print('Training set score: {:.4f}'.format(clf_en.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf_en.score(X_test, y_test)))
# Out:
# Training set score: 1.0000
# Test set score: 1.0000

# %%
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_en.fit(X_train, y_train))
# Out:
# [Text(0.6, 0.8333333333333334, 'x[11] <= 4.5\nentropy = 0.767\nsamples = 67\nvalue = [15, 52]'),
#  Text(0.4, 0.5, 'x[3] <= 1.5\nentropy = 0.48\nsamples = 58\nvalue = [6, 52]'),
#  Text(0.5, 0.6666666666666667, 'True  '),
#  Text(0.2, 0.16666666666666666, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.6, 0.16666666666666666, 'entropy = 0.0\nsamples = 52\nvalue = [0, 52]'),
#  Text(0.8, 0.5, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.7, 0.6666666666666667, '  False')]

# %%
import graphviz
dot_data = tree.export_graphviz(clf_en, out_file=None,
                              feature_names=X_train.columns,
                              class_names=y_train,
                              filled=True, rounded=True,
                              special_characters=True)

graph = graphviz.Source(dot_data)

graph

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_en)

print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[ 6  0]
#  [ 0 27]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_en))
# Out:
#               precision    recall  f1-score   support
#
#        Fraud       1.00      1.00      1.00         6
#       honest       1.00      1.00      1.00        27
#
#     accuracy                           1.00        33
#    macro avg       1.00      1.00      1.00        33
# weighted avg       1.00      1.00      1.00        33

# %% [markdown]
# precisionโมเดลไม่ทำนายผิดเลยในกรณีทั้งสองคลาส
# recallโมเดลสามารถค้นพบข้อมูลทั้งหมดของแต่ละคลาสได้อย่างสมบูรณ์
#  f1-scoreโมเดลมีการทำนายที่สมดุลและแม่นยำ
#  support จำนวนตัวอย่าง ที่มีจริงในแต่ละคลาสในชุดข้อมูลทดสอบ
#  Accuracy: คือ ความถูกต้องทั้งหมด
