# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchada2000/MY-WORK/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
# %matplotlib inline

import os
import pandas as pd
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # นำข้อมูลเข้า

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('/content/drive/MyDrive/project/example.xlsx')

# %%
df.shape #14column 10row
# Out:
# (100, 14)

# %%
df.head()
# Out:
#    ID  Age Gender  Career  No_policy  No_claim  Insurance premium  \
# 0   1   30      m       1          2         1               3000
# 1   2   35      f       4          2         2               5000
# 2   3   21      f       5          3         2               1500
# 3   4   25      f       3          3         1               3500
# 4   5   40      f       1          3         3               4000
#
#   Result_claim  Payment  Time_information Conversation  Speed  Time  result
# 0        claim  on time                 1       normal      1     1  honest
# 1        claim     late                 0       normal      5     2   Fraud
# 2       reject  on time                 0       normal      3     5  honest
# 3       reject  on time                 0          bad      2     4  honest
# 4        claim     late                 2       normal      1     2  honest

# %%
#เปลี่ยนชื่อcolumn ถ้าใน excal โอเคแล้วก็ไม่ต้องเปลี่ยนหรอก
col_names = ['ID_cus','Age_cus','Gender_cus','Career','Number_policy','Number_claim','Insurance Premiun','Result_Claim','Payment','Time_information','Conversation','Speed','Time','Result']


df.columns = col_names

col_names
# Out:
# ['ID_cus',
#  'Age_cus',
#  'Gender_cus',
#  'Career',
#  'Number_policy',
#  'Number_claim',
#  'Insurance Premiun',
#  'Result_Claim',
#  'Payment',
#  'Time_information',
#  'Conversation',
#  'Speed',
#  'Time',
#  'Result']

# %%
df.head()
# Out:
#    ID_cus  Age_cus  Gender_cus  Career  Number_policy  Number_claim  \
# 0       1       30           1       1              2             1
# 1       2       35           0       4              2             2
# 2       3       21           0       5              3             2
# 3       4       25           0       3              3             1
# 4       5       40           0       1              3             3
#
#    Insurance Premiun  Result_Claim  Payment  Time_information  Conversation  \
# 0               3000             0        1                 1             1
# 1               5000             0        0                 0             1
# 2               1500             1        1                 0             1
# 3               3500             1        1                 0             0
# 4               4000             0        0                 2             1
#
#    Speed  Time  Result
# 0      1     1  honest
# 1      5     2   Fraud
# 2      3     5  honest
# ...

# %%
#เปลี่ยนชนิดของข้อมูลให้กลายเป็นตัวเลขทั้งหมด แต่เหลือตัวแปรตามเอาไว้ที่เป็นstr
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Gender_cus'] = le.fit_transform(df['Gender_cus'])
df['Result_Claim'] = le.fit_transform(df['Result_Claim'])
df['Payment'] = le.fit_transform(df['Payment'])
df['Conversation'] = le.fit_transform(df['Conversation'])

# %%
df.head()
# Out:
#    ID_cus  Age_cus  Gender_cus  Career  Number_policy  Number_claim  \
# 0       1       30           1       1              2             1
# 1       2       35           0       4              2             2
# 2       3       21           0       5              3             2
# 3       4       25           0       3              3             1
# 4       5       40           0       1              3             3
#
#    Insurance Premiun  Result_Claim  Payment  Time_information  Conversation  \
# 0               3000             0        1                 1             1
# 1               5000             0        0                 0             1
# 2               1500             1        1                 0             1
# 3               3500             1        1                 0             0
# 4               4000             0        0                 2             1
#
#    Speed  Time  Result
# 0      1     1  honest
# 1      5     2   Fraud
# 2      3     5  honest
# ...

# %%
df.info() #การแจกแจงความถี่คือจำนวนข้อมูลที่มีcolumn นั้น เป็นข้อมูลชนิดไหน
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID_cus             100 non-null    int64
#  1   Age_cus            100 non-null    int64
#  2   Gender_cus         100 non-null    object
#  3   Career             100 non-null    int64
#  4   Number_policy      100 non-null    int64
#  5   Number_claim       100 non-null    int64
#  6   Insurance Premiun  100 non-null    int64
#  7   Result_Claim       100 non-null    object
#  8   Payment            100 non-null    object
#  9   Time_information   100 non-null    int64
#  10  Conversation       100 non-null    object
#  11  Speed              100 non-null    int64
#  12  Time               100 non-null    int64
#  13  Result             100 non-null    object
# dtypes: int64(9), object(5)
# memory usage: 11.1+ KB

# %%
col_names = ['ID_cus','Age_cus','Gender_cus','Career','Number_policy','Number_claim','Insurance Premiun','Result_Claim','Payment','Time_information','Conversation','Speed','Time','Result']


for col in col_names:

    print(df[col].value_counts())
    #ดูจำนวนของแต่ละคอลัมว่ามีข้อมูลแบบไหนกี่จำนวน
# Out:
# ID_cus
# 1      1
# 64     1
# 74     1
# 73     1
# 72     1
#       ..
# 31     1
# 30     1
# 29     1
# 28     1
# 100    1
# Name: count, Length: 100, dtype: int64
# Age_cus
# 23    14
# 45    12
# 21    10
# 22     8
# 65     8
# 20     8
# 30     6
# 2      6
# 28     6
# 3      4
# 67     2
# 77     2
# 43     2
# 6      2
# 25     2
# 33     2
# 29     1
# 35     1
# 57     1
# 60     1
# 44     1
# 40     1
# Name: count, dtype: int64
# Gender_cus
# f    60
# m    40
# Name: count, dtype: int64
# Career
# 1    23
# 3    20
# 5    19
# 8    12
# 9    11
# 4    10
# 2     5
# Name: count, dtype: int64
# Number_policy
# 3    49
# 2    39
# 1    12
# Name: count, dtype: int64
# Number_claim
# 1    51
# 2    40
# 3     9
# Name: count, dtype: int64
# Insurance Premiun
# 5000    22
# 1500    21
# 3500    20
# 3000    10
# 4000     9
# 6500     9
# 2500     9
# Name: count, dtype: int64
# Result_Claim
# claim     51
# reject    49
# Name: count, dtype: int64
# Payment
# ...

# %%
df['Result'].value_counts()  #ดูแยกเป็นชื่อคอลัมเลย
# Out:
# Result
# honest    79
# Fraud     21
# Name: count, dtype: int64

# %%
df.isnull().sum() #เช็ค missing
# Out:
# ID_cus               0
# Age_cus              0
# Gender_cus           0
# Career               0
# Number_policy        0
# Number_claim         0
# Insurance Premiun    0
# Result_Claim         0
# Payment              0
# Time_information     0
# Conversation         0
# Speed                0
# Time                 0
# Result               0
# dtype: int64

# %% [markdown]
# # แยกตัวแปรต้น-ตาม

# %%
x = df.drop(['Result'], axis=1)

y = df['Result']

# %% [markdown]
# # แยก train test

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.40, random_state = 42)
#42เป็นตัวเลขที่หมายถึงการสุ่มซ้ำได้เรื่อย ๆ ไม่ได้มีความมหายอะไรมากก็แค่เป็นเลขอะไรก็ได้ที่เป็นจำนวนเต็ม
#0.40 40%ของการเป็นตัว test

# %%
x_train.shape, x_test.shape
#60แถว(Training set) 13คอลัมน์ 40แถว(Test set)13คอลัมน์
# Out:
# ((60, 13), (40, 13))

# %%
x_train.dtypes
# Out:
# ID_cus                int64
# Age_cus               int64
# Gender_cus           object
# Career                int64
# Number_policy         int64
# Number_claim          int64
# Insurance Premiun     int64
# Result_Claim         object
# Payment              object
# Time_information      int64
# Conversation         object
# Speed                 int64
# Time                  int64
# dtype: object

# %%
x_train
# Out:
#     ID_cus  Age_cus Gender_cus  Career  Number_policy  Number_claim  \
# 49      50       28          f       3              2             1
# 34      35       20          f       3              2             1
# 7        8       57          f       3              2             1
# 95      96       65          f       5              3             2
# 27      28       67          f       1              2             1
# 19      20        3          f       8              1             1
# 81      82       21          f       1              3             2
# 25      26       45          m       3              3             1
# 62      63       20          m       8              1             1
# 13      14       21          f       3              3             1
# 24      25       22          f       5              3             2
# 3        4       25          f       3              3             1
# 17      18       21          f       3              3             1
# ...

# %%
x_train.head()
# Out:
#     ID_cus  Age_cus Gender_cus  Career  Number_policy  Number_claim  \
# 49      50       28          f       3              2             1
# 34      35       20          f       3              2             1
# 7        8       57          f       3              2             1
# 95      96       65          f       5              3             2
# 27      28       67          f       1              2             1
#
#     Insurance Premiun Result_Claim  Payment  Time_information Conversation  \
# 49               3500        claim  on time                 2       normal
# 34               3500        claim  on time                 2       normal
# 7                3500        claim  on time                 2       normal
# 95               1500       reject  on time                 0       normal
# 27               3000        claim  on time                 1       normal
#
#     Speed  Time
# 49      3     2
# 34      3     2
# 7       3     2
# 95      3     5
# 27      1     1

# %%
# !pip install category_encoders

# %%
import category_encoders as ce

# %%
encoder = ce.OrdinalEncoder(cols=['ID_cus','Age_cus','Gender_cus','Career','Number_policy','Number_claim','Insurance Premiun','Result_Claim','Payment','Time_information','Conversation','Speed','Time'])


x_train = encoder.fit_transform(x_train)

x_test = encoder.transform(x_test)
#เอาแค่ตัวแปรที่มีในx
#เป็นการเปลี่ยนชนิดข้อมูลให้กลยเป็นตัวเลข

# %%
x_train.head() #แต่จะทำให้ข้อมูลแปลกๆ
# Out:
#     ID_cus  Age_cus  Gender_cus  Career  Number_policy  Number_claim  \
# 49       1        1           1       1              1             1
# 34       2        2           1       1              1             1
# 7        3        3           1       1              1             1
# 95       4        4           1       2              2             2
# 27       5        5           1       3              1             1
#
#     Insurance Premiun  Result_Claim  Payment  Time_information  Conversation  \
# 49                  1             1        1                 1             1
# 34                  1             1        1                 1             1
# 7                   1             1        1                 1             1
# 95                  2             2        1                 2             1
# 27                  3             1        1                 3             1
#
#     Speed  Time
# 49      1     1
# 34      1     1
# 7       1     1
# 95      1     2
# ...

# %% [markdown]
# # gini

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# สร้างโมเดล
model = DecisionTreeClassifier()

# กำหนดช่วงของ max_depth ที่ต้องการทดสอบ
param_grid = {'max_depth': [3, 5, 10, 15, 20, None]}

# ใช้ GridSearchCV เพื่อหาค่าที่ดีที่สุด
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)
grid_search.fit(x_train, y_train)

# แสดงผลลัพธ์ที่ดีที่สุด
print("Best max_depth:", grid_search.best_params_['max_depth'])
#ช่วยลด overfitting
# Out:
# Best max_depth: 3

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# กำหนดโมเดล
model = DecisionTreeClassifier()

# กำหนดพารามิเตอร์ที่ต้องการทดสอบ
param_grid = {'min_samples_split': [2, 10, 20, 50, 100]}

# ใช้ Grid Search เพื่อหาค่าที่ดีที่สุด
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)
grid_search.fit(x_train, y_train)

# แสดงผลลัพธ์ที่ดีที่สุด
print("Best min_samples_split:", grid_search.best_params_['min_samples_split'])
# Out:
# Best min_samples_split: 2

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# กำหนดโมเดล
model = DecisionTreeClassifier()

# กำหนดพารามิเตอร์ที่ต้องการทดสอบ
param_grid = {'min_samples_leaf': [1, 2, 5, 10, 20]}

# ใช้ Grid Search เพื่อหาค่าที่ดีที่สุด
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)
grid_search.fit(x_train, y_train)

# แสดงผลลัพธ์ที่ดีที่สุด
print("Best min_samples_leaf:", grid_search.best_params_['min_samples_leaf'])
# Out:
# Best min_samples_leaf: 1

# %%
#ดูว่าควรกำหนด max_features และ min_impurity_decrease เป็นเท่าไหร่
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# กำหนดพารามิเตอร์ที่ต้องการลองในช่วงต่างๆ
param_dist = {
    'max_features': ['sqrt', 'log2', None],
    'min_impurity_decrease': np.linspace(0.0, 0.1, 5)  # ลองค่าต่างๆ ตั้งแต่ 0.0 ถึง 0.1
}

# สร้างโมเดล RandomForestClassifier
model = RandomForestClassifier()

# สร้าง RandomizedSearchCV
random_search = RandomizedSearchCV(model, param_dist, n_iter=10, cv=5)  # ทดลอง 10 ชุดค่าพารามิเตอร์

# ฝึกโมเดล
random_search.fit(x_train, y_train)

# แสดงผลลัพธ์ที่ดีที่สุด
print("Best parameters found: ", random_search.best_params_)
# Out:
# Best parameters found:  {'min_impurity_decrease': 0.025, 'max_features': 'log2'}

# %%
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=5, random_state=0,min_samples_split=20,min_samples_leaf=2)


# fit the model
clf_gini.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=20,
#                        random_state=0)

# %%
y_pred_gini = clf_gini.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion gini index: {0:0.4f}'. format(accuracy_score(y_test, y_pred_gini)))
#แสดงความแม่นยำโดยแสดงออกเป็นทศนิยม 4 ตำแหน่ง
#มีความแม่นยำ 95% #จากชุดข้อมูลทดสอบ
# Out:
# Model accuracy score with criterion gini index: 0.9500

# %% [markdown]
# # เปรียบเทียบความแม่นยำของชุดฝึกและชุดทดสอบ

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100)  # สร้าง Random Forest ด้วย 100 ต้นไม้ ต้นไม้มากขึ้นจะทำให้โมเดลมีความแม่นยำสูงขึ้น
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
model = RandomForestClassifier(max_features="log2", min_impurity_decrease=0.025)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(clf_gini, X_train, y_train, cv=5)  # ใช้ 5-fold cross-validation
print(scores)

# %%
y_pred_train_gini = clf_gini.predict(x_train)

y_pred_train_gini
# Out:
# array(['honest', 'honest', 'honest', 'honest', 'honest', 'honest',
#        'honest', 'honest', 'honest', 'honest', 'honest', 'honest',
#        'honest', 'Fraud', 'honest', 'Fraud', 'Fraud', 'honest', 'honest',
#        'Fraud', 'honest', 'Fraud', 'honest', 'Fraud', 'honest', 'honest',
#        'honest', 'Fraud', 'honest', 'honest', 'honest', 'honest', 'Fraud',
#        'Fraud', 'Fraud', 'Fraud', 'honest', 'honest', 'Fraud', 'honest',
#        'Fraud', 'honest', 'honest', 'honest', 'Fraud', 'honest', 'honest',
#        'honest', 'Fraud', 'Fraud', 'honest', 'honest', 'honest', 'honest',
#        'Fraud', 'honest', 'honest', 'honest', 'honest', 'honest'],
#       dtype=object)

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_gini))) #จากชุดข้อมูลฝึกสอน
# Out:
# Training-set accuracy score: 0.9500

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(clf_gini.score(x_train, y_train)))

print('Test set score: {:.4f}'.format(clf_gini.score(x_test, y_test)))
# Out:
# Training set score: 0.9500
# Test set score: 0.9500

# %% [markdown]
# # สร้างภาพ

# %%
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_gini.fit(x_train, y_train))
# Out:
# [Text(0.5, 0.75, 'x[3] <= 4.5\ngini = 0.358\nsamples = 60\nvalue = [14, 46]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 43\nvalue = [0, 43]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.625, 0.5, '  False')]

# %% [markdown]
# # วิธีอ่าน dicision tree

# %% [markdown]
# ![Screenshot 2024-12-01 104915.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# มีความหมายว่าตัวแปรที่ 11 หมายถึง speed จำนวนครั้งของการเร่งรีบ ไม่นัลคอลัมแรกเพราะถือว่าเป็นคอลัม 0 /// มีค่าน้ยกว่า 4.5 จะไปทางซ้าย
#
# gini การตัดสินใจจะแยกโหนดต่อไปเพื่อพยายามลดค่าความไม่บริสุทธิ์นี้ให้ใกล้ 0 มากขึ้น เพื่อให้โหนดปลายทางมีคลาสที่ชัดเจน ในที่นี้มี2class
# value 0=ford 1=honest
# vale =[9,0]แสดงว่า ford

# %%
import numpy as np

num = np.int64(42)  # ตัวแปร numpy.int64
text = "The number is: "

# เกิดข้อผิดพลาด:
# result = text + num  # จะเกิด error

# วิธีแก้ไข:
result = text + str(num)  # แปลง num เป็น str ก่อน
print(result)  # Output: "The number is: 42"

# %%
import graphviz
dot_data = tree.export_graphviz(clf_gini, out_file=None,
                              feature_names=x_train.columns,
                              class_names=y_train,
                              filled=True, rounded=True,
                              special_characters=True)

graph = graphviz.Source(dot_data)

graph

# %%
clf_en = DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=0,min_samples_split=20,min_samples_leaf=2)


# fit the model
clf_en.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=2,
#                        min_samples_split=20, random_state=0)

# %%
y_pred_en = clf_en.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion entropy: {0:0.4f}'. format(accuracy_score(y_test, y_pred_en)))
# Out:
# Model accuracy score with criterion entropy: 0.9500

# %%
y_pred_train_en = clf_en.predict(x_train)

y_pred_train_en
# Out:
# array(['honest', 'honest', 'honest', 'honest', 'honest', 'honest',
#        'honest', 'honest', 'honest', 'honest', 'honest', 'honest',
#        'honest', 'Fraud', 'honest', 'Fraud', 'Fraud', 'honest', 'honest',
#        'Fraud', 'honest', 'Fraud', 'honest', 'Fraud', 'honest', 'honest',
#        'honest', 'Fraud', 'honest', 'honest', 'honest', 'honest', 'Fraud',
#        'Fraud', 'Fraud', 'Fraud', 'honest', 'honest', 'Fraud', 'honest',
#        'Fraud', 'honest', 'honest', 'honest', 'Fraud', 'honest', 'honest',
#        'honest', 'Fraud', 'Fraud', 'honest', 'honest', 'honest', 'honest',
#        'Fraud', 'honest', 'honest', 'honest', 'honest', 'honest'],
#       dtype=object)

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_en)))
# Out:
# Training-set accuracy score: 0.9500

# %%
print('Training set score: {:.4f}'.format(clf_en.score(x_train, y_train)))

print('Test set score: {:.4f}'.format(clf_en.score(x_test, y_test)))
# Out:
# Training set score: 0.9500
# Test set score: 0.9500

# %%
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_en.fit(x_train, y_train))
# Out:
# [Text(0.5, 0.75, 'x[3] <= 4.5\nentropy = 0.784\nsamples = 60\nvalue = [14, 46]'),
#  Text(0.25, 0.25, 'entropy = 0.0\nsamples = 43\nvalue = [0, 43]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'entropy = 0.672\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.625, 0.5, '  False')]

# %%
import graphviz
dot_data = tree.export_graphviz(clf_en, out_file=None,
                              feature_names=x_train.columns,
                              class_names=y_train,
                              filled=True, rounded=True,
                              special_characters=True)

graph = graphviz.Source(dot_data)

graph

# %% [markdown]
# # Confusion matrix

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_en)

print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[ 7  0]
#  [ 2 31]]

# %% [markdown]
# True Positives (TP): จำนวนครั้งที่โมเดลทำนาย คลาส 1 ได้ถูกต้อง
#
# ในที่นี้คือ 31 (Predicted Class 1, Actual Class 1)
# False Positives (FP): จำนวนครั้งที่โมเดลทำนาย คลาส 1 แต่จริงๆ แล้วเป็น คลาส 0
#
# ในที่นี้คือ 0 (Predicted Class 1, Actual Class 0)
# False Negatives (FN): จำนวนครั้งที่โมเดลทำนาย คลาส 0 แต่จริงๆ แล้วเป็น คลาส 1
#
# ในที่นี้คือ 2 (Predicted Class 0, Actual Class 1)
# True Negatives (TN): จำนวนครั้งที่โมเดลทำนาย คลาส 0 ได้ถูกต้อง
#
# ในที่นี้คือ 7 (Predicted Class 0, Actual Class 0)

# %% [markdown]
# # Classification Report

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_en))
# Out:
#               precision    recall  f1-score   support
#
#        Fraud       0.78      1.00      0.88         7
#       honest       1.00      0.94      0.97        33
#
#     accuracy                           0.95        40
#    macro avg       0.89      0.97      0.92        40
# weighted avg       0.96      0.95      0.95        40

# %% [markdown]
# Precision:
#
# Fraud: 0.78 — โมเดลทำนาย Fraud ได้ถูกต้อง 78% เมื่อมันทำนายว่าเป็น Fraud
# honest: 1.00 — โมเดลทำนาย honest ได้ถูกต้อง 100% เมื่อมันทำนายว่าเป็น honest
# Recall:
#
# Fraud: 1.00 — โมเดลสามารถจับ Fraud ได้ทั้งหมด 100% (ไม่พลาดแม้แต่กรณีเดียว)
# honest: 0.94 — โมเดลสามารถจับ honest ได้ 94% ของทั้งหมด
# F1-Score:
#
# Fraud: 0.88 — เป็นค่าเฉลี่ยที่สมดุลระหว่าง Precision และ Recall สำหรับ Fraud
# honest: 0.97 — เป็นค่าเฉลี่ยที่สมดุลระหว่าง Precision และ Recall สำหรับ honest
# Support:
#
# Fraud: 7 — จำนวนของตัวอย่างในชุดทดสอบที่เป็น Fraud
# honest: 33 — จำนวนของตัวอย่างในชุดทดสอบที่เป็น honest
# ค่าเฉลี่ย (Average):
# Accuracy:
#
# ค่า Accuracy คือ 0.95 หรือ 95% หมายความว่า โมเดลทำนายได้ถูกต้อง 95% จากทั้งหมด 40 ตัวอย่างในชุดทดสอบ
# Macro avg:
#
# Precision: 0.89 — คำนวณจากค่า Precision ของทุกคลาสโดยไม่คำนึงถึงจำนวนตัวอย่างในแต่ละคลาส
# Recall: 0.97 — คำนวณจากค่า Recall ของทุกคลาสโดยไม่คำนึงถึงจำนวนตัวอย่างในแต่ละคลาส
# F1-Score: 0.92 — ค่า F1-score เฉลี่ยจากทุกคลาส
# Weighted avg:
#
# Precision: 0.96 — ค่า Precision ที่คำนวณโดยพิจารณาจากจำนวนตัวอย่างของแต่ละคลาส
# Recall: 0.95 — ค่า Recall ที่คำนวณโดยพิจารณาจากจำนวนตัวอย่างของแต่ละคลาส
# F1-Score: 0.95 — ค่า F1-score ที่คำนวณโดยพิจารณาจากจำนวนตัวอย่างของแต่ละคลาส
# สรุป:
# โมเดลทำงานได้ดีมาก โดยมี accuracy = 95% และ f1-score สูง โดยเฉพาะ honest ที่มีค่า f1-score = 0.97 ซึ่งแสดงว่าโมเดลสามารถทำนาย honest ได้ดีมาก
# การทำนาย Fraud มีความแม่นยำค่อนข้างต่ำกว่า honest โดยมี f1-score = 0.88 ซึ่งยังถือว่าอยู่ในระดับที่ดี
# ค่า macro avg และ weighted avg แสดงถึงค่าความสมดุลของโมเดลที่ใช้ทุกคลาสในการคำนวณ ทั้งนี้ weighted avg จะให้ความสำคัญกับคลาสที่มีจำนวนตัวอย่างมากกว่า เช่น honest ที่มี 33 ตัวอย่าง
# ในภาพรวม โมเดลนี้มีการทำงานที่ดีทั้งในด้าน precision, recall, และ f1-score สำหรับทั้งสองคลาส Fraud และ honest.

# %% [markdown]
# precisionโมเดลไม่ทำนายผิดเลยในกรณีทั้งสองคลาส
# recallโมเดลสามารถค้นพบข้อมูลทั้งหมดของแต่ละคลาสได้อย่างสมบูรณ์
#  f1-scoreโมเดลมีการทำนายที่สมดุลและแม่นยำ
#  support จำนวนตัวอย่าง ที่มีจริงในแต่ละคลาสในชุดข้อมูลทดสอบ
#  Accuracy: คือ ความถูกต้องทั้งหมด
